# %% [markdown]
# <a href="https://colab.research.google.com/github/ignatiusharo/ignatiusharo/blob/master/Islavet_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#os.chdir('scripts')

# !python fetch_sale_details.py
# Out:
# CERT_PATH: /content/Islavet-project/cert/api.bsale.io.crt
# El archivo de certificado existe.
# Certificados concatenados en C:\Users\iharo001\OneDrive - Codelco\Capacitación\Curso Python\Islavet\Islavet-project\cert\combined_cert.pem
#                                                  href    id  lineNumber  \
# 0   https://api.bsale.io/v1/documents/2604/details...  4746           0
# 1   https://api.bsale.io/v1/documents/2578/details...  4700           0
# 2   https://api.bsale.io/v1/documents/2579/details...  4701           0
# 3   https://api.bsale.io/v1/documents/2580/details...  4702           0
# 4   https://api.bsale.io/v1/documents/2580/details...  4703           0
# 5   https://api.bsale.io/v1/documents/2581/details...  4704           0
# 6   https://api.bsale.io/v1/documents/2581/details...  4705           0
# 7   https://api.bsale.io/v1/documents/2581/details...  4706           0
# 8   https://api.bsale.io/v1/documents/2581/details...  4707           0
# ...
